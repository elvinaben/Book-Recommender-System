# %% [markdown]
# # Collaborative Filtering-Based Book Recommendation System

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
import sys
print(f"Python Executable: {sys.executable}")
print("Python Path:")
for path in sys.path:
    print(path)
# Out:
# Python Executable: /Users/elvinabenedicta/Desktop/Holiday/Book Recommender System copy/env-RecommenderSystem/bin/python
# Python Path:
# /Users/elvinabenedicta/miniconda3/envs/Fast_API/lib/python311.zip
# /Users/elvinabenedicta/miniconda3/envs/Fast_API/lib/python3.11
# /Users/elvinabenedicta/miniconda3/envs/Fast_API/lib/python3.11/lib-dynload
#
# /Users/elvinabenedicta/Desktop/Holiday/Book Recommender System copy/env-RecommenderSystem/lib/python3.11/site-packages

# %%
books_path = 'books_data/books.csv'
ratings_path = 'books_data/ratings.csv'
users_path = 'books_data/users.csv'

# %% [markdown]
# # Books Dataset

# %%
books_df = pd.read_csv(books_path, sep=';', on_bad_lines='skip', encoding='latin-1')
books_df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books_df.shape
# Out:
# (271360, 8)

# %%
books_df.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %% [markdown]
# All columns have the data type object.

# %%
books_df[books_df['ISBN'].str.contains(r'\D', regex=True)]
# Out:
#               ISBN                                         Book-Title  \
# 9       074322678X            Where You'll Find Me: And Other Stories
# 11      080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 40      038078243X                   Miss Zukas and the Raven's Dance
# 41      055321215X                                Pride and Prejudice
# 42      067176537X  The Therapeutic Touch: How to Use Your Hands t...
# ...            ...                                                ...
# 271323  000637610X                                   You Got an Ology
# 271335  381440176X  Ein Fall fÃ?Â¼r TKKG, Bd.50, Sklaven fÃ?Â¼r Wu...
# 271343  020130998X  The Unified Modeling Language Reference Manual...
# 271353  014002803X                                  Anti Death League
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
#
#              Book-Author Year-Of-Publication                    Publisher  \
# ...

# %% [markdown]
# It turns out that there are ISBN values containing letters, so the data type will remain object.

# %%
books_df['Year-Of-Publication'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No missing values were found in Year-Of-Publication.

# %%
print(books_df['Year-Of-Publication'].unique())
# Out:
# [2002 2001 1991 1999 2000 1993 1996 1988 2004 1998 1994 2003 1997 1983
#  1979 1995 1982 1985 1992 1986 1978 1980 1952 1987 1990 1981 1989 1984 0
#  1968 1961 1958 1974 1976 1971 1977 1975 1965 1941 1970 1962 1973 1972
#  1960 1966 1920 1956 1959 1953 1951 1942 1963 1964 1969 1954 1950 1967
#  2005 1957 1940 1937 1955 1946 1936 1930 2011 1925 1948 1943 1947 1945
#  1923 2020 1939 1926 1938 2030 1911 1904 1949 1932 1928 1929 1927 1931
#  1914 2050 1934 1910 1933 1902 1924 1921 1900 2038 2026 1944 1917 1901
#  2010 1908 1906 1935 1806 2021 '2000' '1995' '1999' '2004' '2003' '1990'
#  '1994' '1986' '1989' '2002' '1981' '1993' '1983' '1982' '1976' '1991'
#  '1977' '1998' '1992' '1996' '0' '1997' '2001' '1974' '1968' '1987' '1984'
#  '1988' '1963' '1956' '1970' '1985' '1978' '1973' '1980' '1979' '1975'
#  '1969' '1961' '1965' '1939' '1958' '1950' '1953' '1966' '1971' '1959'
#  '1972' '1955' '1957' '1945' '1960' '1967' '1932' '1924' '1964' '2012'
# ...

# %% [markdown]
# Numeric and string data were found, so everything will be converted to strings. Then, data that are non-numeric and have a value of 0 will be deleted.

# %% [markdown]
# ### Changing the column 'Year-Of-Publication' to string.

# %%
books_df['Year-Of-Publication'] = books_df['Year-Of-Publication'].astype(str)

# %%
print(books_df['Year-Of-Publication'].unique())
# Out:
# ['2002' '2001' '1991' '1999' '2000' '1993' '1996' '1988' '2004' '1998'
#  '1994' '2003' '1997' '1983' '1979' '1995' '1982' '1985' '1992' '1986'
#  '1978' '1980' '1952' '1987' '1990' '1981' '1989' '1984' '0' '1968' '1961'
#  '1958' '1974' '1976' '1971' '1977' '1975' '1965' '1941' '1970' '1962'
#  '1973' '1972' '1960' '1966' '1920' '1956' '1959' '1953' '1951' '1942'
#  '1963' '1964' '1969' '1954' '1950' '1967' '2005' '1957' '1940' '1937'
#  '1955' '1946' '1936' '1930' '2011' '1925' '1948' '1943' '1947' '1945'
#  '1923' '2020' '1939' '1926' '1938' '2030' '1911' '1904' '1949' '1932'
#  '1928' '1929' '1927' '1931' '1914' '2050' '1934' '1910' '1933' '1902'
#  '1924' '1921' '1900' '2038' '2026' '1944' '1917' '1901' '2010' '1908'
#  '1906' '1935' '1806' '2021' '2012' '2006' 'DK Publishing Inc' 'Gallimard'
#  '1909' '2008' '1378' '1919' '1922' '1897' '2024' '1376' '2037']

# %% [markdown]
# It can now be observed that all values in the 'Year-Of-Publication' column have been converted to strings. However, there are entries with text values and the number 0, which is not a valid publication year. Therefore, data with these values will be removed.

# %% [markdown]
# ### Removing invalid 'Year-Of-Publication' values

# %%
books_df = books_df[books_df['Year-Of-Publication'].str.isdigit()]
books_df = books_df[books_df['Year-Of-Publication'] != '0']

# %% [markdown]
# ### Convert the 'Year-Of-Publication' data type to int.

# %%
books_df['Year-Of-Publication'] = books_df['Year-Of-Publication'].astype(int)

# %%
print(books_df['Year-Of-Publication'].unique())
print(books_df['Year-Of-Publication'].dtype)
# Out:
# [2002 2001 1991 1999 2000 1993 1996 1988 2004 1998 1994 2003 1997 1983
#  1979 1995 1982 1985 1992 1986 1978 1980 1952 1987 1990 1981 1989 1984
#  1968 1961 1958 1974 1976 1971 1977 1975 1965 1941 1970 1962 1973 1972
#  1960 1966 1920 1956 1959 1953 1951 1942 1963 1964 1969 1954 1950 1967
#  2005 1957 1940 1937 1955 1946 1936 1930 2011 1925 1948 1943 1947 1945
#  1923 2020 1939 1926 1938 2030 1911 1904 1949 1932 1928 1929 1927 1931
#  1914 2050 1934 1910 1933 1902 1924 1921 1900 2038 2026 1944 1917 1901
#  2010 1908 1906 1935 1806 2021 2012 2006 1909 2008 1378 1919 1922 1897
#  2024 1376 2037]
# int64

# %% [markdown]
# Now all the data in 'Year-Of-Publication' is clean and correct, and its data type has been converted to integer.

# %%
books_df.shape
# Out:
# (266739, 8)

# %%
books_df.nunique()
# Out:
# ISBN                   266739
# Book-Title             238511
# Book-Author            100667
# Year-Of-Publication       115
# Publisher               16394
# Image-URL-S            266430
# Image-URL-M            266430
# Image-URL-L            266430
# dtype: int64

# %% [markdown]
# All ISBN values are unique, as indicated by the number of rows in the data matching the count of unique ISBN values.

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 266739 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 266739 non-null  object
#  1   Book-Title           266739 non-null  object
#  2   Book-Author          266737 non-null  object
#  3   Year-Of-Publication  266739 non-null  int64
#  4   Publisher            266737 non-null  object
#  5   Image-URL-S          266739 non-null  object
#  6   Image-URL-M          266739 non-null  object
#  7   Image-URL-L          266739 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 18.3+ MB

# %% [markdown]
# Missing values were found in the 'Book-Author' and 'Publisher' columns.

# %% [markdown]
# ### Drop Missing Value in'Book-Author' and 'Publisher'

# %%
books_df.dropna(subset=['Book-Author', 'Publisher'], inplace=True)

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 266735 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 266735 non-null  object
#  1   Book-Title           266735 non-null  object
#  2   Book-Author          266735 non-null  object
#  3   Year-Of-Publication  266735 non-null  int64
#  4   Publisher            266735 non-null  object
#  5   Image-URL-S          266735 non-null  object
#  6   Image-URL-M          266735 non-null  object
#  7   Image-URL-L          266735 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 18.3+ MB

# %% [markdown]
# There are no missing values remaining in the data.

# %%
books_df['Book-Title'].value_counts()
# Out:
# Book-Title
# Selected Poems                                                                                                                    27
# Little Women                                                                                                                      22
# Wuthering Heights                                                                                                                 20
# Dracula                                                                                                                           20
# Adventures of Huckleberry Finn                                                                                                    20
#                                                                                                                                   ..
# Raising Depression-Free Children: A Parent's Guide to Prevention and Early Intervention                                            1
# ...

# %%
selected_poems_df = books_df[books_df['Book-Title'] == 'Selected Poems']
print(selected_poems_df)
# Out:
#               ISBN      Book-Title                 Book-Author  \
# 4523    081120958X  Selected Poems     William Carlos Williams
# 39416   0811201465  Selected Poems                  K. Patchen
# 41316   0679750800  Selected Poems                   Rita Dove
# 106885  0060931744  Selected Poems            Gwendolyn Brooks
# 118775  0517101548  Selected Poems                  John Donne
# 127462  0520012984  Selected Poems               Paul Verlaine
# 156894  0871401541  Selected Poems              E. E. Cummings
# 158312  0060909897  Selected Poems            Gwendolyn Brooks
# 175602  0571050190  Selected Poems         T.           T Gunn
# 183908  1550651498  Selected Poems             Ralph Gustafson
# 184897  0333516265  Selected Poems                Thomas Hardy
# 189247  0679430830  Selected Poems                   Rita Dove
# 189963  0940262193  Selected Poems              Kathleen Raine
# 196944  0802151027  Selected Poems                Pablo Neruda
# ...

# %% [markdown]
# For the book titled "Selected Poems," it turns out that all of its authors are different.

# %%
little_women_df = books_df[books_df['Book-Title'] == 'Little Women']
print(little_women_df)
# Out:
#               ISBN    Book-Title        Book-Author  Year-Of-Publication  \
# 3952    185854176X  Little Women   Louisa M. Atcott                 1995
# 12227   0590203509  Little Women  Louisa May Alcott                 1994
# 20676   0440447682  Little Women  Louisa May Alcott                 1990
# 52210   0451529308  Little Women  Louisa May Alcott                 2004
# 52551   0451518144  Little Women  Louisa May Alcott                 1983
# 53358   0590437976  Little Women  Louisa May Alcott                 1992
# 57432   0195813898  Little Women             Alcott                 1985
# 72168   0785788727  Little Women  Louisa May Alcott                 1999
# 82565   0448110199  Little Women  Louisa May Alcott                 1981
# 84807   0812523334  Little Women  Louisa May Alcott                 1994
# 110746  0394562798  Little Women  Louisa May Alcott                 1988
# 118219  1557042160  Little Women      Laurie Lawlor                 1994
# ...

# %% [markdown]
# For the book titled "Little Women," although the ISBNs are different, the author is the same: Louisa May Alcott. This indicates that different publication years or times result in different ISBNs for each edition of the book.

# %%
print(books_df['Image-URL-S'][0])
print(books_df['Image-URL-M'][0])
print(books_df['Image-URL-L'][0])
# Out:
# http://images.amazon.com/images/P/0195153448.01.THUMBZZZ.jpg
# http://images.amazon.com/images/P/0195153448.01.MZZZZZZZ.jpg
# http://images.amazon.com/images/P/0195153448.01.LZZZZZZZ.jpg

# %% [markdown]
# ### Image with different sizes.
# Image-URL-S
# ![Alt Text](http://images.amazon.com/images/P/0195153448.01.THUMBZZZ.jpg)
#
# Image-URL-M
# ![Alt Text](http://images.amazon.com/images/P/0195153448.01.MZZZZZZZ.jpg)
#
# Image-URL-L
# ![Alt Text](http://images.amazon.com/images/P/0195153448.01.LZZZZZZZ.jpg)

# %% [markdown]
# Since larger sizes tend to be clearer, the large image URL (L) will be used, and the small (S) and medium (M) sizes will be dropped.

# %%
books_df.drop(columns=['Image-URL-S', 'Image-URL-M'], inplace=True)

# %%
books_df.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-L'],
#       dtype='object')

# %% [markdown]
# # Ratings Dataset

# %%
ratings_df = pd.read_csv(ratings_path, sep=';', on_bad_lines='skip', encoding='latin-1')
ratings_df.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings_df.shape
# Out:
# (1149780, 3)

# %% [markdown]
# In the rating dataset, there are 3 columns and 1,149,780 records.

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
ratings_df.isna().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %% [markdown]
# In the ratings dataset, no missing values were found and the data types are also correct.

# %%
ratings_df.nunique()
# Out:
# User-ID        105283
# ISBN           340556
# Book-Rating        11
# dtype: int64

# %%
ratings_df['Book-Rating'].value_counts()
# Out:
# Book-Rating
# 0     716109
# 8     103736
# 10     78610
# 7      76457
# 9      67541
# 5      50974
# 6      36924
# 4       8904
# 3       5996
# 2       2759
# 1       1770
# Name: count, dtype: int64

# %% [markdown]
# In the dataset description, it is stated that the book rating range is on a scale of 1-10. A value of 0 represents an implicit rating, indicating that users might not have explicitly rated the book.

# %%
ratings_df['User-ID'].value_counts()
# Out:
# User-ID
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %% [markdown]
# The user with the most ratings is the one with ID 11676, who has given 13,602 ratings.

# %% [markdown]
# # Merge books_df and ratings_df

# %%
books_and_ratings = ratings_df.merge(books_df, on="ISBN")
books_and_ratings.head(3)
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title      Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel       M. J. Rose
# 1   276726  0155061224            5      Rites of Passage       Judith Rae
# 2   276727  0446520802            0          The Notebook  Nicholas Sparks
#
#    Year-Of-Publication         Publisher  \
# 0                 2002  Ballantine Books
# 1                 2001            Heinle
# 2                 1996      Warner Books
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/0155061224.0...
# 2  http://images.amazon.com/images/P/0446520802.0...

# %%
books_and_ratings.shape
# Out:
# (1017119, 8)

# %%
books_and_ratings.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating', 'Book-Title', 'Book-Author',
#        'Year-Of-Publication', 'Publisher', 'Image-URL-L'],
#       dtype='object')

# %% [markdown]
# # Users Dataset

# %% [markdown]
# This dataset is not used in this project, but I performed a brief analysis of it.

# %%
users_df = pd.read_csv(users_path, sep=';', on_bad_lines='skip', encoding='latin-1')
users_df.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users_df.shape
# Out:
# (278858, 3)

# %% [markdown]
# The dataset contains 3 columns and 278,858 records.

# %%
users_df.nunique()
# Out:
# User-ID     278858
# Location     57339
# Age            165
# dtype: int64

# %% [markdown]
# All User-IDs are unique.

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
users_df.isna().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %% [markdown]
# Age has 110,762 missing values.

# %%
users_df['Location'].value_counts()
# Out:
# Location
# london, england, united kingdom                  2506
# toronto, ontario, canada                         2250
# sydney, new south wales, australia               1744
# melbourne, victoria, australia                   1708
# portland, oregon, usa                            1629
#                                                  ...
# gneisenaustr. 3, nordrhein-westfalen, germany       1
# -, bayern, germany                                  1
# bouchegouf, guelma, algeria                         1
# indiana and philadelphia, pennsylvania, usa         1
# tacoma, washington, united kingdom                  1
# Name: count, Length: 57339, dtype: int64

# %% [markdown]
# ### Age missing values

# %%
missing_age_count = users_df['Age'].isna().sum()
total_age_count = len(users_df['Age'])
non_missing_age_count = total_age_count - missing_age_count

percent_missing = (missing_age_count / total_age_count) * 100
percent_not_missing = 100 - percent_missing

labels = ['Missing', 'Not Missing']
sizes = [percent_missing, percent_not_missing]
colors = ['#ff9999', '#66b3ff']

plt.figure(figsize=(3, 3))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Age Missing Value Percentage')
plt.axis('equal')  

plt.show()

# %% [markdown]
# Almost 40% of the Age values are missing. Therefore, Age will not be used as a feature influencing this book recommendation system. However, to provide an overview of the age distribution, I have created the histogram below.

# %%
age_data = users_df['Age'].dropna()

min_age = int(age_data.min())
max_age = int(age_data.max())

bins = list(range(min_age, max_age + 10, 10))  

plt.figure(figsize=(10, 6))
plt.hist(age_data, bins=bins, edgecolor='black', color='#66b3ff')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)

plt.show()

# %% [markdown]
# It can be observed that the majority of users (whose data is not missing) fall within the age range of 20 to 50 years.

# %% [markdown]
# ## Filter

# %% [markdown]
# ### Filter 1: Group by `Book-Title` and count how many users have interacted with each book. In `Action-Count`, we include all interactions, including those where the `Book-Rating` is 0.

# %%
action_count = books_and_ratings.groupby('Book-Title')['Book-Rating'].count().reset_index()
action_count.head()
# Out:
#                                           Book-Title  Book-Rating
# 0   A Light in the Storm: The Civil War Diary of ...            4
# 1                              Always Have Popsicles            1
# 2               Apple Magic (The Collector's series)            1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4   Beyond IBM: Leadership Marketing and Finance ...            1

# %%
action_count.rename(columns={'Book-Rating': 'Action-Count'}, inplace=True)
action_count.head()
# Out:
#                                           Book-Title  Action-Count
# 0   A Light in the Storm: The Civil War Diary of ...             4
# 1                              Always Have Popsicles             1
# 2               Apple Magic (The Collector's series)             1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...             1
# 4   Beyond IBM: Leadership Marketing and Finance ...             1

# %% [markdown]
# ### Filter 2: Group by `Book-Title` and count how many users have given explicit ratings on a scale from 1 to 10. Therefore, a `Book-Rating` of 0 will not be included in the `Rating-Count`.

# %%
filtered_ratings = books_and_ratings[books_and_ratings['Book-Rating'] > 0]
rating_count = filtered_ratings.groupby('Book-Title')['Book-Rating'].count().reset_index()

rating_count.rename(columns={'Book-Rating': 'Rating-Count'}, inplace=True)
rating_count.head()
# Out:
#                                           Book-Title  Rating-Count
# 0   A Light in the Storm: The Civil War Diary of ...             1
# 1   Ask Lily (Young Women of Faith: Lily Series, ...             1
# 2                                       Dark Justice             1
# 3   Earth Prayers From around the World: 365 Pray...             7
# 4   Final Fantasy Anthology: Official Strategy Gu...             2

# %% [markdown]
# ### Merging Action Counts and Rating Counts into the Main DataFrame

# %%
final_df = books_and_ratings.merge(action_count, on='Book-Title')
final_df = final_df.merge(rating_count, on='Book-Title')
final_df.head(2)
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1   276726  0155061224            5      Rites of Passage  Judith Rae
#
#    Year-Of-Publication         Publisher  \
# 0                 2002  Ballantine Books
# 1                 2001            Heinle
#
#                                          Image-URL-L  Action-Count  \
# 0  http://images.amazon.com/images/P/034545104X.0...            60
# 1  http://images.amazon.com/images/P/0155061224.0...             5
#
#    Rating-Count
# 0            28
# 1             1

# %%
final_df.shape
# Out:
# (860174, 10)

# %%
duplicate_entries = final_df.groupby(['User-ID', 'Book-Title']).size().reset_index(name='count')
duplicates_more_than_once = duplicate_entries[duplicate_entries['count'] > 1]
print(duplicates_more_than_once)
# Out:
#         User-ID                                         Book-Title  count
# 314         254                                       Cat's Cradle      2
# 365         254   Harry Potter and the Chamber of Secrets (Book 2)      2
# 368         254  Harry Potter and the Prisoner of Azkaban (Book 3)      2
# 397         254                                 Martian Chronicles      2
# 410         254                                         Neverwhere      2
# ...         ...                                                ...    ...
# 854801   278418                                  The Street Lawyer      2
# 854831   278418                                        The Witness      2
# 854852   278418                                         Thumbelina      2
# 854920   278418                                           Vanished      2
# 854962   278418            Wee Sing Nursery Rhymes &amp; Lullabies      2
#
# [4370 rows x 3 columns]

# %% [markdown]
# ### Remove Duplicate Records with Identical Book-Title and User-ID Pairs

# %%
final_df.drop_duplicates(['Book-Title', 'User-ID'], inplace=True)

# %%
final_df.shape
# Out:
# (855607, 10)

# %% [markdown]
# ### Filter 3: Filter books that have been reviewed at least 50 times (minimum Rating-Count of 50) or have a minimum Action-Count of 100.

# %%
final_df = final_df[(final_df['Rating-Count'] >= 50) | (final_df['Action-Count'] >= 100)]
final_df.head()
# Out:
#    User-ID        ISBN  Book-Rating           Book-Title      Book-Author  \
# 2   276727  0446520802            0         The Notebook  Nicholas Sparks
# 6   276744  038550120X            7      A Painted House     JOHN GRISHAM
# 7   276746  0425115801            0            Lightning   Dean R. Koontz
# 8   276746  0449006522            0  Manhattan Hunt Club        JOHN SAUL
# 9   276746  0553561618            0        Dark Paradise        TAMI HOAG
#
#    Year-Of-Publication                 Publisher  \
# 2                 1996              Warner Books
# 6                 2001                 Doubleday
# 7                 1996  Berkley Publishing Group
# 8                 2002          Ballantine Books
# 9                 1994                    Bantam
#
#                                          Image-URL-L  Action-Count  \
# 2  http://images.amazon.com/images/P/0446520802.0...           650
# 6  http://images.amazon.com/images/P/038550120X.0...           838
# ...

# %% [markdown]
# # Convert to Pivot Table

# %%
books_pivot = final_df.pivot_table(columns='User-ID', index='Book-Title', values='Book-Rating')
books_pivot
# Out:
# User-ID                                             8       9       14      \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
books_pivot.shape
# Out:
# (920, 38062)

# %% [markdown]
# ### Filling Missing Values with 0

# %%
books_pivot.fillna(0, inplace=True)
books_pivot
# Out:
# User-ID                                             8       9       14      \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %% [markdown]
# # 1. Using Cosine Similarity

# %% [markdown]
# ### Calculating Similarity Between Books

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(books_pivot)
book_similarity_df = pd.DataFrame(similarity, index=books_pivot.index, columns=books_pivot.index)

# %%
def recommend_books(book_title, top_n=8):
    similar_scores = book_similarity_df[book_title]
    similar_books = similar_scores.sort_values(ascending=False).drop(book_title).head(top_n)
    
    return similar_books

# %%
recommendations = recommend_books('Harry Potter and the Chamber of Secrets (Book 2)')
print(recommendations)
# Out:
# Book-Title
# Harry Potter and the Prisoner of Azkaban (Book 3)                   0.532624
# Harry Potter and the Goblet of Fire (Book 4)                        0.511679
# Harry Potter and the Sorcerer's Stone (Book 1)                      0.383957
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))    0.303902
# Harry Potter and the Order of the Phoenix (Book 5)                  0.296864
# The Fellowship of the Ring (The Lord of the Rings, Part 1)          0.132119
# The Reptile Room (A Series of Unfortunate Events, Book 2)           0.098910
# The Two Towers (The Lord of the Rings, Part 2)                      0.098397
# Name: Harry Potter and the Chamber of Secrets (Book 2), dtype: float64

# %% [markdown]
# ## 2. Using KNN

# %%
from scipy.sparse import csr_matrix

book_sparse = csr_matrix(books_pivot)
book_sparse
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 74947 stored elements and shape (920, 38062)>

# %%
from sklearn.neighbors import NearestNeighbors

knn_model1 = NearestNeighbors( algorithm='brute')
knn_model1.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
def knn_recommend_books(book_title, model, n_recommendations=8, print_distance=False):
    book_idx = books_pivot.index.get_loc(book_title)

    # Find the distances and indices of the nearest neighbors
    distances, indices = model.kneighbors(book_sparse[book_idx], n_neighbors=n_recommendations+1)
    
    # Get the titles of the recommended books (excluding the input book itself)
    recommended_books = books_pivot.index[indices.flatten()[1:]]
    recommended_distances = distances.flatten()[1:]  # Exclude the first distance (the book itself)
    
    print(f"Recommendations for '{book_title}':")
    for i, (book, distance) in enumerate(zip(recommended_books, recommended_distances), 1):
        if print_distance:  # If print_distance is True
            print(f"{i}. {book} (Distance: {distance:.4f})")
        else:
            print(f"{i}. {book}")

# %%
knn_recommend_books('Harry Potter and the Chamber of Secrets (Book 2)', knn_model1, print_distance=True)
# Out:
# Recommendations for 'Harry Potter and the Chamber of Secrets (Book 2)':
# 1. Harry Potter and the Goblet of Fire (Book 4) (Distance: 149.9767)
# 2. Harry Potter and the Prisoner of Azkaban (Book 3) (Distance: 150.0633)
# 3. Harry Potter and the Sorcerer's Stone (Book 1) (Distance: 158.4866)
# 4. The Sands of Time (Distance: 161.2886)
# 5. Whirlwind (Tyler, Book 1) (Distance: 161.5735)
# 6. The Laws of Our Fathers (Distance: 161.6385)
# 7. Zoya (Distance: 161.7251)
# 8. Kaleidoscope (Distance: 161.8827)

# %% [markdown]
# When comparing the recommendation results from Cosine Similarity with the results from the KNN brute algorithm for the test case book 'Harry Potter and the Chamber of Secrets (Book 2)', I believe Cosine Similarity provides better results.
#
# Cosine Similarity Recommendations:
#
# Harry Potter and the Prisoner of Azkaban (Book 3)                   0.532624
#
# Harry Potter and the Goblet of Fire (Book 4)                        0.511679
#
# Harry Potter and the Sorcerer's Stone (Book 1)                      0.383957
#
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))    0.303902
#
# Harry Potter and the Order of the Phoenix (Book 5)                  0.296864
#
# The Fellowship of the Ring (The Lord of the Rings, Part 1)          0.132119
#
# The Reptile Room (A Series of Unfortunate Events, Book 2)           0.098910
#
# The Two Towers (The Lord of the Rings, Part 2)                      0.098397
#
#
# For Cosine Similarity recommendations, numbers 1-5 are Harry Potter series books, and recommendations 6-8 are books with a concept somewhat similar to Harry Potter.
#
#
# In contrast, with the KNN brute algorithm recommendations, numbers 1-3 are Harry Potter books. However, recommendations 4-8 are books that are not relevant to Harry Potter.
#
#
# Therefore, it can be concluded that the Cosine Similarity method is suitable for use here.

# %% [markdown]
# # KNN with Cosine Metric

# %%
knn_model2 = NearestNeighbors( algorithm='brute', metric='cosine')
knn_model2.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
knn_recommend_books('Harry Potter and the Chamber of Secrets (Book 2)', knn_model2, print_distance=True)
# Out:
# Recommendations for 'Harry Potter and the Chamber of Secrets (Book 2)':
# 1. Harry Potter and the Prisoner of Azkaban (Book 3) (Distance: 0.4674)
# 2. Harry Potter and the Goblet of Fire (Book 4) (Distance: 0.4883)
# 3. Harry Potter and the Sorcerer's Stone (Book 1) (Distance: 0.6160)
# 4. Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback)) (Distance: 0.6961)
# 5. Harry Potter and the Order of the Phoenix (Book 5) (Distance: 0.7031)
# 6. The Fellowship of the Ring (The Lord of the Rings, Part 1) (Distance: 0.8679)
# 7. The Reptile Room (A Series of Unfortunate Events, Book 2) (Distance: 0.9011)
# 8. The Two Towers (The Lord of the Rings, Part 2) (Distance: 0.9016)

# %% [markdown]
# It can be observed that both Cosine Similarity and KNN yield similar recommendation results. The distance values in the KNN model are equal to 1 minus the similarity scores from Cosine Similarity.

# %%
knn_recommend_books('Harry Potter and the Chamber of Secrets (Book 2)', knn_model2)
# Out:
# Recommendations for 'Harry Potter and the Chamber of Secrets (Book 2)':
# 1. Harry Potter and the Prisoner of Azkaban (Book 3)
# 2. Harry Potter and the Goblet of Fire (Book 4)
# 3. Harry Potter and the Sorcerer's Stone (Book 1)
# 4. Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# 5. Harry Potter and the Order of the Phoenix (Book 5)
# 6. The Fellowship of the Ring (The Lord of the Rings, Part 1)
# 7. The Reptile Room (A Series of Unfortunate Events, Book 2)
# 8. The Two Towers (The Lord of the Rings, Part 2)

# %% [markdown]
# For the deployment process, I will use the KNN model with the Cosine Metric.

# %%
import pickle as pkl

pkl.dump(knn_model2, open('artifacts/knn_model.pkl', 'wb'))
pkl.dump(final_df, open('artifacts/final_data.pkl', 'wb'))
pkl.dump(books_pivot, open('artifacts/book_pivot.pkl', 'wb'))
